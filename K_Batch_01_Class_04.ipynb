# %% [markdown]
# <a href="https://colab.research.google.com/github/mdrashedulhasan1/K-Batch-01-Class-04/blob/main/K_Batch_01_Class_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# #Multiple Input
# x,y = int(input("Input x:")),int(input("Input y:"))
# result = x+y
# print("Result is:",result)

#Loop
# x = [2, 3, 5, 6]
# for i in x:
#   print(i) 

# for rashedul in [2, 4, 6, "tapu", 45.34]:
#   print(rashedul)

# for i in range(10):
#   print(i)

# for i in range(1,10,2):
#   print(i)

# for i in range(10,0,-2):
#   print(i)

# for i in range(1,11):
#   if(i%2!=0):
#     print(i,"Odd number")
#   else:
#     print(i,"Even number")

# for i in range(1,4):
#   result = int(input())
#   print(result)

# list = []
# for i in range(0,2):
#   allNumber = input()
#   list.append(allNumber)
#   print(list)
# x = int(list[0])
# y = int(list[1])
# result = x+y
# print("Total result is:",result)

# for i in range(5):
#   if i==2:
#     continue  #Skip
#   print(i)

# for i in range(5):
#   if i==2:
#     break
#   print(i)

# for i in range(5):
#   if i==2:
#     pass
#     print("Found!")
#   print(i)


# *****
# *****
# *****
# *****
# *****
# for i in range(5):
#   for j in range(5):
#     print("*",end="")
#   print()


# *
# **
# ***
# ****
# *****

# for i in range(25):
#   for i in range(i+1):
#     print("*",end="")
#   print()

#      *
#     **
#    ***
#   ****
#  *****
# for i in range(5):
#   for j in range(4-i):
#     print(" ",end="")
#   for k in range(i+1):
#     print("*",end="")
#   print()

# *****
# ****
# ***
# **
# *

# for i in range(5):
#   for j in range(5-i):
#     print("*",end="")
#   print()


# *****
#  ****
#   ***
#    **
#     *

# for i in range(5):
#   for j in range(i):
#     print(" ",end="")
#   for k in range(5-i):
#     print("*",end="")
#   print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# ************
# *************
# **************
# ***************
# ****************
# *****************
# ******************
# *******************
# ********************
# *********************
# **********************
# ***********************
# ************************
# *************************
